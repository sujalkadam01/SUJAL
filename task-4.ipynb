# %% [markdown]
# Name: Sujal Vitthal Kadam || Branch: co || Task = 4

# %%
import matplotlib.pyplot as plt

# %%
sem = [1,2,3,4]
marks = [49,59,46,61]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('dark_background')

plt.grid(True)

plt.show()

# %%
sem = [1,2,3,4]
marks = [69,75,73,83]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('ggplot')

plt.grid(True)

plt.show()

# %%
sem = [1,2,3,4]
marks = [46,49,59,61]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('bmh')

plt.grid(True)

plt.show()

# %%
sem = [1,2,3,4]
marks = [43,49,60,39]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('_classic_test_patch')

plt.grid(True)

plt.show()

# %%
sem = [1,2,3,4]
marks = [70,65,47,80]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('Solarize_Light2')
plt.grid(True)

plt.show()

# %%
sem = [1,2,3,4]
marks = [62,56,78,76]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('grayscale')

plt.grid(True)

plt.show()

# %%
sem = [1,2,3,4]
marks = [76,88,40,67]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('seaborn-v0_8')

plt.grid(True)

plt.show()

# %%
sem = [1,2,3,4]
marks = [61,58,47,68]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('fivethirtyeight')

plt.grid(True)

plt.show()

# %%
sem = [1,2,3,4]
marks = [46,49,59,61]
plt.plot(sem,marks)
plt.ylabel("Marks")
plt.xlabel("SEM")
plt.title("Performance")
plt.style.use('classic')

plt.grid(True)

plt.show()
